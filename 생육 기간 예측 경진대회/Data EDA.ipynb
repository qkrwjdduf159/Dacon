# %% [markdown]
# 출처 : https://dacon.io/competitions/official/235851/codeshare/3772?page=1&dtype=recent

# %%
from PIL import Image

Image.open('/content/drive/MyDrive/데이콘/생육/KakaoTalk_20211126_010619892.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1440 at 0x7F5EC1B10890>

# %% [markdown]
# ## 이미지 데이터의 구조도

# %%
# # 데이터 압축 풀기
# path_to_zip_file = '/content/drive/MyDrive/데이콘/생육/Data/open.zip'
# directory_extract_file = '/content/drive/MyDrive/데이콘/생육/Data'

# import zipfile
# with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
#   zip_ref.extractall(directory_extract_file)

# %%
# 모듈 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob

test_csv = pd.read_csv('/content/drive/MyDrive/데이콘/생육/Data/open/test_dataset/test_data.csv')

# %% [markdown]
# ## Train 전처리

# %%
Train_path = '/content/drive/MyDrive/데이콘/생육/Data/open/train_dataset'

def extract_day(file_name):
  day = int(file_name.split('.')[-2][-2:])
  return day

# %% [markdown]
# ## Test 전처리

# %%
test_csv
# Out:
#        idx   before_file_path    after_file_path
# 0        0  idx_LT_1003_00341  idx_LT_1003_00154
# 1        1  idx_LT_1003_00592  idx_LT_1003_00687
# 2        2  idx_BC_1100_00445  idx_BC_1100_00840
# 3        3  idx_BC_1112_00229  idx_BC_1112_00105
# 4        4  idx_LT_1088_00681  idx_LT_1088_00698
# ...    ...                ...                ...
# 3955  3955  idx_BC_1100_00110  idx_BC_1100_00525
# 3956  3956  idx_LT_1089_00006  idx_LT_1089_00442
# 3957  3957  idx_BC_1100_00511  idx_BC_1100_00132
# 3958  3958  idx_BC_1088_00353  idx_BC_1088_00196
# 3959  3959  idx_BC_1100_00527  idx_BC_1100_00640
#
# [3960 rows x 3 columns]

# %%
PATH = '/content/drive/MyDrive/데이콘/생육/Data/open/test_dataset'
# Out:
# 0       LT/1003/00341
# 1       LT/1003/00592
# 2       BC/1100/00445
# 3       BC/1112/00229
# 4       LT/1088/00681
#             ...
# 3955    BC/1100/00110
# 3956    LT/1089/00006
# 3957    BC/1100/00511
# 3958    BC/1088/00353
# 3959    BC/1100/00527
# Name: before_file_path, Length: 3960, dtype: object
